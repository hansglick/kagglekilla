# %%
import dill as pickle
import pandas as pd
import numpy as np
from shutil import copyfile
import sys
import os
from sklearn import *
sys.path.append("../fun")
from fun import *
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Define run ID

# %%
settingsID = define_settings_id()

# %% [markdown]
# ### Load data

# %%
files = [f for f in os.listdir('.') if os.path.isfile(f)]

if "all_setting_results.pkl" in files:
    infile = open("all_setting_results.pkl",'rb')
    all_setting_results = pickle.load(infile)
    infile.close()
else:
    all_setting_results = {}

# %%
infile = open("../features/all_datasets_for_modeling.pkl",'rb')
all_datasets_for_modeling = pickle.load(infile)
infile.close()

# %%
infile = open("../features/build_train_test_for_model_parameters.pkl",'rb')
build_train_test_for_model_parameters= pickle.load(infile)
infile.close()

# %% [markdown]
# #### Metric de comparaison

# %%
def customscoring(y, y_pred):
    return metrics.mean_squared_error(y,y_pred)
myscoringfun = metrics.make_scorer(customscoring, greater_is_better=False)

# %% [markdown]
# #### Tout les modèles au sens large à tester

# %%
dic_of_models = {1:ensemble.RandomForestRegressor(),2:linear_model.Ridge()}

param_list_model_1 = [{"max_depth":np.random.randint(low=1,high=15,size=5), "random_state":0, "n_estimators":499,
                       "search_scoring" : myscoringfun,"search_cv":3, "search_n_jobs":2, "search_n_iter" : 3}]
param_list_model_2 = [{"random_state":1,"alpha":3, "split_test_size":0.45,"split_random_state":55},
                     {"random_state":999,"alpha":0.1}]
dic_of_hyparam = {1: param_list_model_1,
                  2: param_list_model_2}

# %% [markdown]
# #### Launch the big Run

# %%
results_of_the_run_settings = run_all_settings(all_datasets_for_modeling,
                                               dic_of_models,
                                               dic_of_hyparam,
                                               build_train_test_for_model_parameters,
                                               customscoring)
# Out:
# ID :  count_global_1.0
#  Feature Strate :  global
#  Target :  count
#  Dataset :  global
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.3858855996813459
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_global_2.0
#  Feature Strate :  global
#  Target :  count
#  Dataset :  global
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.078822630055252
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_global_2.1
#  Feature Strate :  global
#  Target :  count
#  Dataset :  global
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.0949178565118407
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_global_1.0
#  Feature Strate :  global
#  Target :  registered
#  Dataset :  global
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.411945708705977
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_global_2.0
#  Feature Strate :  global
#  Target :  registered
#  Dataset :  global
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.095011816137343
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_global_2.1
#  Feature Strate :  global
#  Target :  registered
#  Dataset :  global
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.0843226690356838
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_global_1.0
#  Feature Strate :  global
#  Target :  casual
#  Dataset :  global
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.3983108118206359
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_global_2.0
#  Feature Strate :  global
#  Target :  casual
#  Dataset :  global
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.8996399450967826
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_global_2.1
#  Feature Strate :  global
#  Target :  casual
#  Dataset :  global
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.8816507146911142
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_workingday.0_1.0
#  Feature Strate :  workingday
#  Target :  count
#  Dataset :  workingday_0
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.41993397136567173
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_workingday.0_2.0
#  Feature Strate :  workingday
#  Target :  count
#  Dataset :  workingday_0
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.8440541969182036
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_workingday.0_2.1
#  Feature Strate :  workingday
#  Target :  count
#  Dataset :  workingday_0
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.8431319629710183
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_workingday.1_1.0
#  Feature Strate :  workingday
#  Target :  count
#  Dataset :  workingday_1
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.35101921815892256
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_workingday.1_2.0
#  Feature Strate :  workingday
#  Target :  count
#  Dataset :  workingday_1
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.134446594773716
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  count_workingday.1_2.1
#  Feature Strate :  workingday
#  Target :  count
#  Dataset :  workingday_1
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.1449340998943154
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_workingday.0_1.0
#  Feature Strate :  workingday
#  Target :  registered
#  Dataset :  workingday_0
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.4473725462863695
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_workingday.0_2.0
#  Feature Strate :  workingday
#  Target :  registered
#  Dataset :  workingday_0
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.803279320945594
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_workingday.0_2.1
#  Feature Strate :  workingday
#  Target :  registered
#  Dataset :  workingday_0
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.8082301001280012
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_workingday.1_1.0
#  Feature Strate :  workingday
#  Target :  registered
#  Dataset :  workingday_1
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.37093125669236177
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_workingday.1_2.0
#  Feature Strate :  workingday
#  Target :  registered
#  Dataset :  workingday_1
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.2008538862641631
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  registered_workingday.1_2.1
#  Feature Strate :  workingday
#  Target :  registered
#  Dataset :  workingday_1
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.2430422262399798
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_workingday.0_1.0
#  Feature Strate :  workingday
#  Target :  casual
#  Dataset :  workingday_0
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.4240392809031775
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_workingday.0_2.0
#  Feature Strate :  workingday
#  Target :  casual
#  Dataset :  workingday_0
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.9955699361048262
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_workingday.0_2.1
#  Feature Strate :  workingday
#  Target :  casual
#  Dataset :  workingday_0
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  1.0064763840516162
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_workingday.1_1.0
#  Feature Strate :  workingday
#  Target :  casual
#  Dataset :  workingday_1
#
# Type :  RandomizedSearchCV
#  Model :  RandomForestRegressor
#  Infos :  {'scoring': make_scorer(customscoring, greater_is_better=False), 'cv': 3, 'n_jobs': 2, 'n_iter': 3}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Nombre de modèles testés :  3
#  Score :  0.3826572833604821
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_workingday.1_2.0
#  Feature Strate :  workingday
#  Target :  casual
#  Dataset :  workingday_1
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {'test_size': 0.45, 'random_state': 55}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.7891039850367001
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *
#
# ID :  casual_workingday.1_2.1
#  Feature Strate :  workingday
#  Target :  casual
#  Dataset :  workingday_1
#
# Type :  holdout
#  Model :  Ridge
#  Infos :  {}
#  Features Number :  21
#  Features Names :  ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'dataset', 'OHE_day_0', 'OHE_day_1', 'OHE_day_2', 'OHE_day_3', 'OHE_day_4', 'OHE_day_5', 'OHE_day_6', 'LE_day', 'LE_month', 'ORE_hour', 'ORE_weather']
#  Score :  0.77001699674481
#
#  * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# #### Stocking and Saving Run Results

# %%
all_setting_results[settingsID] = results_of_the_run_settings
filename = 'all_setting_results.pkl'
outfile = open(filename,'wb')
pickle.dump(all_setting_results,outfile)
outfile.close()

# %% [markdown]
# #### Saving all notebooks written for this run in the results folder

# %%
folderpath = "results/"+settingsID
if not os.path.isdir(folderpath):
    os.mkdir("results/"+settingsID)

files_to_copy = listfiles_fromfolders([".","../features","../fun"])
copyfiles_to_folder(files_to_copy,folderpath)
